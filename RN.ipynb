# %% [markdown]
# 개발 환경 세팅

# %%
# !pip install gymnasium
# !pip install sb3_contrib
# Out:
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.11/dist-packages (1.1.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (4.13.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (0.0.4)
# Collecting sb3_contrib
#   Downloading sb3_contrib-2.6.0-py3-none-any.whl.metadata (4.1 kB)
# Collecting stable_baselines3<3.0,>=2.6.0 (from sb3_contrib)
#   Downloading stable_baselines3-2.6.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: gymnasium<1.2.0,>=0.29.1 in /usr/local/lib/python3.11/dist-packages (from stable_baselines3<3.0,>=2.6.0->sb3_contrib) (1.1.1)
# Requirement already satisfied: numpy<3.0,>=1.20 in /usr/local/lib/python3.11/dist-packages (from stable_baselines3<3.0,>=2.6.0->sb3_contrib) (2.0.2)
# Requirement already satisfied: torch<3.0,>=2.3 in /usr/local/lib/python3.11/dist-packages (from stable_baselines3<3.0,>=2.6.0->sb3_contrib) (2.6.0+cu124)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from stable_baselines3<3.0,>=2.6.0->sb3_contrib) (3.1.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from stable_baselines3<3.0,>=2.6.0->sb3_contrib) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from stable_baselines3<3.0,>=2.6.0->sb3_contrib) (3.10.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium<1.2.0,>=0.29.1->stable_baselines3<3.0,>=2.6.0->sb3_contrib) (4.13.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium<1.2.0,>=0.29.1->stable_baselines3<3.0,>=2.6.0->sb3_contrib) (0.0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3_contrib) (3.18.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3_contrib) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3_contrib) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3_contrib) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3_contrib)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3_contrib)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3_contrib)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3_contrib)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3_contrib)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3_contrib)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3_contrib)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3_contrib)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3_contrib)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3_contrib) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3_contrib) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3_contrib) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3_contrib)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3_contrib) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3_contrib) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3_contrib) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3<3.0,>=2.6.0->sb3_contrib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3<3.0,>=2.6.0->sb3_contrib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3<3.0,>=2.6.0->sb3_contrib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3<3.0,>=2.6.0->sb3_contrib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3<3.0,>=2.6.0->sb3_contrib) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3<3.0,>=2.6.0->sb3_contrib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3<3.0,>=2.6.0->sb3_contrib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3<3.0,>=2.6.0->sb3_contrib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->stable_baselines3<3.0,>=2.6.0->sb3_contrib) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->stable_baselines3<3.0,>=2.6.0->sb3_contrib) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->stable_baselines3<3.0,>=2.6.0->sb3_contrib) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3_contrib) (3.0.2)
# Downloading sb3_contrib-2.6.0-py3-none-any.whl (92 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.8/92.8 kB 3.0 MB/s eta 0:00:00
# Downloading stable_baselines3-2.6.0-py3-none-any.whl (184 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.5/184.5 kB 7.6 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 60.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 66.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 30.2 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.3 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.3 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.3 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 64.8 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, stable_baselines3, sb3_contrib
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 sb3_contrib-2.6.0 stable_baselines3-2.6.0

# %% [markdown]
# 구글 드라이브와 연결

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# 학습 시작

# %%
import os
print(os.getcwd())  # 현재 작업 디렉토리 출력

os.chdir("/content/drive/My Drive/RN")  # 원하는 폴더로 이동
print(os.getcwd())  # 변경된 디렉토리 확인

# !python "./learn.py"
# Out:
# Streaming output truncated to the last 5000 lines.
# |    loss                 | 711        |
# |    n_updates            | 33130      |
# |    policy_gradient_loss | -0.029     |
# |    value_loss           | 1.53e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.85        |
# |    ep_rew_mean          | 57.8        |
# | time/                   |             |
# |    fps                  | 128         |
# |    iterations           | 33          |
# |    time_elapsed         | 526         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.023711681 |
# |    clip_fraction        | 0.218       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.64       |
# |    explained_variance   | 0.191       |
# |    learning_rate        | 0.01        |
# |    loss                 | 755         |
# |    n_updates            | 33140       |
# |    policy_gradient_loss | -0.0342     |
# |    value_loss           | 1.53e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.59        |
# |    ep_rew_mean          | 58          |
# | time/                   |             |
# |    fps                  | 128         |
# |    iterations           | 34          |
# |    time_elapsed         | 541         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.026972894 |
# |    clip_fraction        | 0.237       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.66       |
# |    explained_variance   | 0.232       |
# |    learning_rate        | 0.01        |
# |    loss                 | 722         |
# |    n_updates            | 33150       |
# |    policy_gradient_loss | -0.0306     |
# |    value_loss           | 1.46e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.3         |
# |    ep_rew_mean          | 51.3        |
# | time/                   |             |
# |    fps                  | 128         |
# |    iterations           | 35          |
# |    time_elapsed         | 556         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.023993425 |
# |    clip_fraction        | 0.224       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.66       |
# |    explained_variance   | 0.224       |
# |    learning_rate        | 0.01        |
# |    loss                 | 743         |
# |    n_updates            | 33160       |
# |    policy_gradient_loss | -0.0342     |
# |    value_loss           | 1.55e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.52        |
# |    ep_rew_mean          | 48          |
# | time/                   |             |
# |    fps                  | 128         |
# |    iterations           | 36          |
# |    time_elapsed         | 572         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.020193793 |
# |    clip_fraction        | 0.201       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.59       |
# |    explained_variance   | 0.173       |
# |    learning_rate        | 0.01        |
# |    loss                 | 765         |
# |    n_updates            | 33170       |
# |    policy_gradient_loss | -0.0314     |
# |    value_loss           | 1.62e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.29        |
# |    ep_rew_mean          | 63.4        |
# | time/                   |             |
# |    fps                  | 128         |
# |    iterations           | 37          |
# |    time_elapsed         | 588         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.022791177 |
# |    clip_fraction        | 0.28        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.63       |
# |    explained_variance   | 0.204       |
# |    learning_rate        | 0.01        |
# |    loss                 | 1.65e+03    |
# |    n_updates            | 33180       |
# |    policy_gradient_loss | -0.0184     |
# |    value_loss           | 2.72e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.37        |
# |    ep_rew_mean          | 58.3        |
# | time/                   |             |
# |    fps                  | 128         |
# |    iterations           | 38          |
# |    time_elapsed         | 604         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.020855904 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.66       |
# |    explained_variance   | 0.142       |
# |    learning_rate        | 0.01        |
# |    loss                 | 790         |
# |    n_updates            | 33190       |
# |    policy_gradient_loss | -0.032      |
# |    value_loss           | 1.66e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.83        |
# |    ep_rew_mean          | 48.7        |
# | time/                   |             |
# |    fps                  | 128         |
# |    iterations           | 39          |
# |    time_elapsed         | 620         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.019001175 |
# |    clip_fraction        | 0.199       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.71       |
# |    explained_variance   | 0.158       |
# |    learning_rate        | 0.01        |
# |    loss                 | 795         |
# |    n_updates            | 33200       |
# |    policy_gradient_loss | -0.0323     |
# |    value_loss           | 1.61e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.64        |
# |    ep_rew_mean          | 62          |
# | time/                   |             |
# |    fps                  | 128         |
# |    iterations           | 40          |
# |    time_elapsed         | 636         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.026153913 |
# |    clip_fraction        | 0.234       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.68       |
# |    explained_variance   | 0.141       |
# |    learning_rate        | 0.01        |
# |    loss                 | 765         |
# |    n_updates            | 33210       |
# |    policy_gradient_loss | -0.0377     |
# |    value_loss           | 1.6e+03     |
# -----------------------------------------
# model_up saved
# Training model_9
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Loaded existing model: ./model_down (Continuing training)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4.37     |
# |    ep_rew_mean     | 35       |
# | time/              |          |
# |    fps             | 132      |
# |    iterations      | 1        |
# |    time_elapsed    | 15       |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.93        |
# |    ep_rew_mean          | 31.4        |
# | time/                   |             |
# |    fps                  | 122         |
# |    iterations           | 2           |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.022829283 |
# |    clip_fraction        | 0.24        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.57       |
# |    explained_variance   | 0.143       |
# |    learning_rate        | 0.01        |
# |    loss                 | 752         |
# |    n_updates            | 37090       |
# |    policy_gradient_loss | -0.0424     |
# |    value_loss           | 1.54e+03    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5.1       |
# |    ep_rew_mean          | 41.4      |
# | time/                   |           |
# |    fps                  | 119       |
# |    iterations           | 3         |
# |    time_elapsed         | 51        |
# |    total_timesteps      | 6144      |
# | train/                  |           |
# |    approx_kl            | 0.0237311 |
# |    clip_fraction        | 0.236     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.53     |
# |    explained_variance   | 0.114     |
# |    learning_rate        | 0.01      |
# |    loss                 | 740       |
# |    n_updates            | 37100     |
# |    policy_gradient_loss | -0.0403   |
# |    value_loss           | 1.53e+03  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5.38      |
# |    ep_rew_mean          | 41.1      |
# | time/                   |           |
# |    fps                  | 118       |
# |    iterations           | 4         |
# |    time_elapsed         | 69        |
# |    total_timesteps      | 8192      |
# | train/                  |           |
# |    approx_kl            | 0.0289596 |
# |    clip_fraction        | 0.252     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.57     |
# |    explained_variance   | 0.172     |
# |    learning_rate        | 0.01      |
# |    loss                 | 705       |
# |    n_updates            | 37110     |
# |    policy_gradient_loss | -0.0485   |
# |    value_loss           | 1.45e+03  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.41        |
# |    ep_rew_mean          | 57.2        |
# | time/                   |             |
# |    fps                  | 119         |
# |    iterations           | 5           |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.030289821 |
# |    clip_fraction        | 0.247       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.56       |
# |    explained_variance   | 0.146       |
# |    learning_rate        | 0.01        |
# |    loss                 | 756         |
# |    n_updates            | 37120       |
# |    policy_gradient_loss | -0.0431     |
# |    value_loss           | 1.55e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.01        |
# |    ep_rew_mean          | 44.5        |
# | time/                   |             |
# |    fps                  | 117         |
# |    iterations           | 6           |
# |    time_elapsed         | 104         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.024869893 |
# |    clip_fraction        | 0.232       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.58       |
# |    explained_variance   | 0.14        |
# |    learning_rate        | 0.01        |
# |    loss                 | 734         |
# |    n_updates            | 37130       |
# |    policy_gradient_loss | -0.039      |
# |    value_loss           | 1.53e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.66       |
# |    ep_rew_mean          | 46.9       |
# | time/                   |            |
# |    fps                  | 118        |
# |    iterations           | 7          |
# |    time_elapsed         | 121        |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.03077345 |
# |    clip_fraction        | 0.242      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.55      |
# |    explained_variance   | 0.177      |
# |    learning_rate        | 0.01       |
# |    loss                 | 748        |
# |    n_updates            | 37140      |
# |    policy_gradient_loss | -0.039     |
# |    value_loss           | 1.47e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.93        |
# |    ep_rew_mean          | 43.5        |
# | time/                   |             |
# |    fps                  | 118         |
# |    iterations           | 8           |
# |    time_elapsed         | 137         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.029973593 |
# |    clip_fraction        | 0.247       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.56       |
# |    explained_variance   | 0.171       |
# |    learning_rate        | 0.01        |
# |    loss                 | 686         |
# |    n_updates            | 37150       |
# |    policy_gradient_loss | -0.0416     |
# |    value_loss           | 1.39e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.42        |
# |    ep_rew_mean          | 38          |
# | time/                   |             |
# |    fps                  | 119         |
# |    iterations           | 9           |
# |    time_elapsed         | 154         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.026238907 |
# |    clip_fraction        | 0.262       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.52       |
# |    explained_variance   | 0.18        |
# |    learning_rate        | 0.01        |
# |    loss                 | 759         |
# |    n_updates            | 37160       |
# |    policy_gradient_loss | -0.0448     |
# |    value_loss           | 1.5e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.87        |
# |    ep_rew_mean          | 37.6        |
# | time/                   |             |
# |    fps                  | 117         |
# |    iterations           | 10          |
# |    time_elapsed         | 174         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.026885811 |
# |    clip_fraction        | 0.247       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.54       |
# |    explained_variance   | 0.126       |
# |    learning_rate        | 0.01        |
# |    loss                 | 750         |
# |    n_updates            | 37170       |
# |    policy_gradient_loss | -0.0418     |
# |    value_loss           | 1.54e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.6         |
# |    ep_rew_mean          | 46.9        |
# | time/                   |             |
# |    fps                  | 117         |
# |    iterations           | 11          |
# |    time_elapsed         | 191         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.031037064 |
# |    clip_fraction        | 0.254       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.53       |
# |    explained_variance   | 0.139       |
# |    learning_rate        | 0.01        |
# |    loss                 | 741         |
# |    n_updates            | 37180       |
# |    policy_gradient_loss | -0.0421     |
# |    value_loss           | 1.47e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.07        |
# |    ep_rew_mean          | 40.4        |
# | time/                   |             |
# |    fps                  | 117         |
# |    iterations           | 12          |
# |    time_elapsed         | 208         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.026869293 |
# |    clip_fraction        | 0.255       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.55       |
# |    explained_variance   | 0.197       |
# |    learning_rate        | 0.01        |
# |    loss                 | 682         |
# |    n_updates            | 37190       |
# |    policy_gradient_loss | -0.0366     |
# |    value_loss           | 1.44e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.33        |
# |    ep_rew_mean          | 37.1        |
# | time/                   |             |
# |    fps                  | 116         |
# |    iterations           | 13          |
# |    time_elapsed         | 227         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.020635488 |
# |    clip_fraction        | 0.221       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.58       |
# |    explained_variance   | 0.133       |
# |    learning_rate        | 0.01        |
# |    loss                 | 756         |
# |    n_updates            | 37200       |
# |    policy_gradient_loss | -0.0341     |
# |    value_loss           | 1.62e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.18        |
# |    ep_rew_mean          | 43.3        |
# | time/                   |             |
# |    fps                  | 116         |
# |    iterations           | 14          |
# |    time_elapsed         | 245         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.027152086 |
# |    clip_fraction        | 0.243       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.54       |
# |    explained_variance   | 0.134       |
# |    learning_rate        | 0.01        |
# |    loss                 | 674         |
# |    n_updates            | 37210       |
# |    policy_gradient_loss | -0.0434     |
# |    value_loss           | 1.43e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.15        |
# |    ep_rew_mean          | 37.3        |
# | time/                   |             |
# |    fps                  | 116         |
# |    iterations           | 15          |
# |    time_elapsed         | 263         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.023320444 |
# |    clip_fraction        | 0.243       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.54       |
# |    explained_variance   | 0.129       |
# |    learning_rate        | 0.01        |
# |    loss                 | 729         |
# |    n_updates            | 37220       |
# |    policy_gradient_loss | -0.0347     |
# |    value_loss           | 1.54e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.15       |
# |    ep_rew_mean          | 48.4       |
# | time/                   |            |
# |    fps                  | 115        |
# |    iterations           | 16         |
# |    time_elapsed         | 282        |
# |    total_timesteps      | 32768      |
# | train/                  |            |
# |    approx_kl            | 0.02688339 |
# |    clip_fraction        | 0.234      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.57      |
# |    explained_variance   | 0.191      |
# |    learning_rate        | 0.01       |
# |    loss                 | 707        |
# |    n_updates            | 37230      |
# |    policy_gradient_loss | -0.0362    |
# |    value_loss           | 1.49e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.94        |
# |    ep_rew_mean          | 43.5        |
# | time/                   |             |
# |    fps                  | 115         |
# |    iterations           | 17          |
# |    time_elapsed         | 300         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.025873896 |
# |    clip_fraction        | 0.236       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.57       |
# |    explained_variance   | 0.134       |
# |    learning_rate        | 0.01        |
# |    loss                 | 774         |
# |    n_updates            | 37240       |
# |    policy_gradient_loss | -0.0433     |
# |    value_loss           | 1.58e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.88        |
# |    ep_rew_mean          | 40.6        |
# | time/                   |             |
# |    fps                  | 115         |
# |    iterations           | 18          |
# |    time_elapsed         | 318         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.021908857 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.57       |
# |    explained_variance   | 0.11        |
# |    learning_rate        | 0.01        |
# |    loss                 | 1.14e+03    |
# |    n_updates            | 37250       |
# |    policy_gradient_loss | -0.0232     |
# |    value_loss           | 2.64e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.97        |
# |    ep_rew_mean          | 41.5        |
# | time/                   |             |
# |    fps                  | 115         |
# |    iterations           | 19          |
# |    time_elapsed         | 336         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.022718087 |
# |    clip_fraction        | 0.237       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.53       |
# |    explained_variance   | 0.109       |
# |    learning_rate        | 0.01        |
# |    loss                 | 748         |
# |    n_updates            | 37260       |
# |    policy_gradient_loss | -0.0374     |
# |    value_loss           | 1.5e+03     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.88       |
# |    ep_rew_mean          | 36.5       |
# | time/                   |            |
# |    fps                  | 115        |
# |    iterations           | 20         |
# |    time_elapsed         | 353        |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.02527472 |
# |    clip_fraction        | 0.23       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.59      |
# |    explained_variance   | 0.193      |
# |    learning_rate        | 0.01       |
# |    loss                 | 713        |
# |    n_updates            | 37270      |
# |    policy_gradient_loss | -0.0372    |
# |    value_loss           | 1.49e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.21       |
# |    ep_rew_mean          | 32.2       |
# | time/                   |            |
# |    fps                  | 115        |
# |    iterations           | 21         |
# |    time_elapsed         | 370        |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.02530245 |
# |    clip_fraction        | 0.238      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.55      |
# |    explained_variance   | 0.115      |
# |    learning_rate        | 0.01       |
# |    loss                 | 754        |
# |    n_updates            | 37280      |
# |    policy_gradient_loss | -0.0327    |
# |    value_loss           | 1.52e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.75        |
# |    ep_rew_mean          | 36.7        |
# | time/                   |             |
# |    fps                  | 116         |
# |    iterations           | 22          |
# |    time_elapsed         | 387         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.025100272 |
# |    clip_fraction        | 0.227       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.57       |
# |    explained_variance   | 0.188       |
# |    learning_rate        | 0.01        |
# |    loss                 | 718         |
# |    n_updates            | 37290       |
# |    policy_gradient_loss | -0.0418     |
# |    value_loss           | 1.5e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.51        |
# |    ep_rew_mean          | 42          |
# | time/                   |             |
# |    fps                  | 116         |
# |    iterations           | 23          |
# |    time_elapsed         | 405         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.026956994 |
# |    clip_fraction        | 0.254       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.55       |
# |    explained_variance   | 0.21        |
# |    learning_rate        | 0.01        |
# |    loss                 | 716         |
# |    n_updates            | 37300       |
# |    policy_gradient_loss | -0.0393     |
# |    value_loss           | 1.41e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.82        |
# |    ep_rew_mean          | 45.7        |
# | time/                   |             |
# |    fps                  | 116         |
# |    iterations           | 24          |
# |    time_elapsed         | 422         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.030139778 |
# |    clip_fraction        | 0.251       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.54       |
# |    explained_variance   | 0.16        |
# |    learning_rate        | 0.01        |
# |    loss                 | 662         |
# |    n_updates            | 37310       |
# |    policy_gradient_loss | -0.0377     |
# |    value_loss           | 1.41e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.2         |
# |    ep_rew_mean          | 48.3        |
# | time/                   |             |
# |    fps                  | 116         |
# |    iterations           | 25          |
# |    time_elapsed         | 439         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.023262026 |
# |    clip_fraction        | 0.231       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.53       |
# |    explained_variance   | 0.177       |
# |    learning_rate        | 0.01        |
# |    loss                 | 684         |
# |    n_updates            | 37320       |
# |    policy_gradient_loss | -0.0387     |
# |    value_loss           | 1.41e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.79       |
# |    ep_rew_mean          | 45.7       |
# | time/                   |            |
# |    fps                  | 116        |
# |    iterations           | 26         |
# |    time_elapsed         | 458        |
# |    total_timesteps      | 53248      |
# | train/                  |            |
# |    approx_kl            | 0.02636465 |
# |    clip_fraction        | 0.217      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.52      |
# |    explained_variance   | 0.16       |
# |    learning_rate        | 0.01       |
# |    loss                 | 735        |
# |    n_updates            | 37330      |
# |    policy_gradient_loss | -0.0386    |
# |    value_loss           | 1.5e+03    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.53        |
# |    ep_rew_mean          | 41.9        |
# | time/                   |             |
# |    fps                  | 115         |
# |    iterations           | 27          |
# |    time_elapsed         | 476         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.031115916 |
# |    clip_fraction        | 0.265       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.52       |
# |    explained_variance   | 0.176       |
# |    learning_rate        | 0.01        |
# |    loss                 | 686         |
# |    n_updates            | 37340       |
# |    policy_gradient_loss | -0.0434     |
# |    value_loss           | 1.41e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.25        |
# |    ep_rew_mean          | 42.2        |
# | time/                   |             |
# |    fps                  | 116         |
# |    iterations           | 28          |
# |    time_elapsed         | 493         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.027956823 |
# |    clip_fraction        | 0.23        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.59       |
# |    explained_variance   | 0.194       |
# |    learning_rate        | 0.01        |
# |    loss                 | 726         |
# |    n_updates            | 37350       |
# |    policy_gradient_loss | -0.0372     |
# |    value_loss           | 1.48e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.38        |
# |    ep_rew_mean          | 37          |
# | time/                   |             |
# |    fps                  | 116         |
# |    iterations           | 29          |
# |    time_elapsed         | 509         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.025617346 |
# |    clip_fraction        | 0.232       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.54       |
# |    explained_variance   | 0.212       |
# |    learning_rate        | 0.01        |
# |    loss                 | 700         |
# |    n_updates            | 37360       |
# |    policy_gradient_loss | -0.039      |
# |    value_loss           | 1.45e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.98       |
# |    ep_rew_mean          | 37.5       |
# | time/                   |            |
# |    fps                  | 116        |
# |    iterations           | 30         |
# |    time_elapsed         | 526        |
# |    total_timesteps      | 61440      |
# | train/                  |            |
# |    approx_kl            | 0.02757091 |
# |    clip_fraction        | 0.239      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.52      |
# |    explained_variance   | 0.17       |
# |    learning_rate        | 0.01       |
# |    loss                 | 743        |
# |    n_updates            | 37370      |
# |    policy_gradient_loss | -0.0368    |
# |    value_loss           | 1.53e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.74       |
# |    ep_rew_mean          | 47.8       |
# | time/                   |            |
# |    fps                  | 116        |
# |    iterations           | 31         |
# |    time_elapsed         | 545        |
# |    total_timesteps      | 63488      |
# | train/                  |            |
# |    approx_kl            | 0.02368117 |
# |    clip_fraction        | 0.233      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.56      |
# |    explained_variance   | 0.143      |
# |    learning_rate        | 0.01       |
# |    loss                 | 746        |
# |    n_updates            | 37380      |
# |    policy_gradient_loss | -0.04      |
# |    value_loss           | 1.55e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.06       |
# |    ep_rew_mean          | 33.3       |
# | time/                   |            |
# |    fps                  | 116        |
# |    iterations           | 32         |
# |    time_elapsed         | 562        |
# |    total_timesteps      | 65536      |
# | train/                  |            |
# |    approx_kl            | 0.02767429 |
# |    clip_fraction        | 0.243      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.56      |
# |    explained_variance   | 0.124      |
# |    learning_rate        | 0.01       |
# |    loss                 | 770        |
# |    n_updates            | 37390      |
# |    policy_gradient_loss | -0.0392    |
# |    value_loss           | 1.58e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.94        |
# |    ep_rew_mean          | 38.5        |
# | time/                   |             |
# |    fps                  | 116         |
# |    iterations           | 33          |
# |    time_elapsed         | 579         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.028929178 |
# |    clip_fraction        | 0.249       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.56       |
# |    explained_variance   | 0.16        |
# |    learning_rate        | 0.01        |
# |    loss                 | 748         |
# |    n_updates            | 37400       |
# |    policy_gradient_loss | -0.0409     |
# |    value_loss           | 1.54e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.73        |
# |    ep_rew_mean          | 38.7        |
# | time/                   |             |
# |    fps                  | 116         |
# |    iterations           | 34          |
# |    time_elapsed         | 595         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.029564008 |
# |    clip_fraction        | 0.257       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.53       |
# |    explained_variance   | 0.1         |
# |    learning_rate        | 0.01        |
# |    loss                 | 744         |
# |    n_updates            | 37410       |
# |    policy_gradient_loss | -0.0401     |
# |    value_loss           | 1.57e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.84       |
# |    ep_rew_mean          | 47.7       |
# | time/                   |            |
# |    fps                  | 116        |
# |    iterations           | 35         |
# |    time_elapsed         | 614        |
# |    total_timesteps      | 71680      |
# | train/                  |            |
# |    approx_kl            | 0.02530708 |
# |    clip_fraction        | 0.234      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.54      |
# |    explained_variance   | 0.14       |
# |    learning_rate        | 0.01       |
# |    loss                 | 759        |
# |    n_updates            | 37420      |
# |    policy_gradient_loss | -0.0348    |
# |    value_loss           | 1.57e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.69        |
# |    ep_rew_mean          | 44.8        |
# | time/                   |             |
# |    fps                  | 116         |
# |    iterations           | 36          |
# |    time_elapsed         | 631         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.025789505 |
# |    clip_fraction        | 0.241       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.53       |
# |    explained_variance   | 0.182       |
# |    learning_rate        | 0.01        |
# |    loss                 | 666         |
# |    n_updates            | 37430       |
# |    policy_gradient_loss | -0.041      |
# |    value_loss           | 1.43e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.65       |
# |    ep_rew_mean          | 39.8       |
# | time/                   |            |
# |    fps                  | 116        |
# |    iterations           | 37         |
# |    time_elapsed         | 649        |
# |    total_timesteps      | 75776      |
# | train/                  |            |
# |    approx_kl            | 0.02666578 |
# |    clip_fraction        | 0.251      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.52      |
# |    explained_variance   | 0.12       |
# |    learning_rate        | 0.01       |
# |    loss                 | 775        |
# |    n_updates            | 37440      |
# |    policy_gradient_loss | -0.0429    |
# |    value_loss           | 1.61e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.09        |
# |    ep_rew_mean          | 49.5        |
# | time/                   |             |
# |    fps                  | 116         |
# |    iterations           | 38          |
# |    time_elapsed         | 669         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.023510695 |
# |    clip_fraction        | 0.222       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.52       |
# |    explained_variance   | 0.145       |
# |    learning_rate        | 0.01        |
# |    loss                 | 763         |
# |    n_updates            | 37450       |
# |    policy_gradient_loss | -0.0415     |
# |    value_loss           | 1.56e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.5         |
# |    ep_rew_mean          | 53.1        |
# | time/                   |             |
# |    fps                  | 116         |
# |    iterations           | 39          |
# |    time_elapsed         | 686         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.024915589 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.52       |
# |    explained_variance   | 0.16        |
# |    learning_rate        | 0.01        |
# |    loss                 | 765         |
# |    n_updates            | 37460       |
# |    policy_gradient_loss | -0.0342     |
# |    value_loss           | 1.52e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.38        |
# |    ep_rew_mean          | 34          |
# | time/                   |             |
# |    fps                  | 116         |
# |    iterations           | 40          |
# |    time_elapsed         | 703         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.025644302 |
# |    clip_fraction        | 0.222       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.53       |
# |    explained_variance   | 0.151       |
# |    learning_rate        | 0.01        |
# |    loss                 | 734         |
# |    n_updates            | 37470       |
# |    policy_gradient_loss | -0.0354     |
# |    value_loss           | 1.55e+03    |
# -----------------------------------------
# model_down saved
# Training model_10
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Loaded existing model: ./model_up (Continuing training)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.38     |
# |    ep_rew_mean     | 54.2     |
# | time/              |          |
# |    fps             | 141      |
# |    iterations      | 1        |
# |    time_elapsed    | 14       |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.64        |
# |    ep_rew_mean          | 34.8        |
# | time/                   |             |
# |    fps                  | 127         |
# |    iterations           | 2           |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.023229169 |
# |    clip_fraction        | 0.224       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.67       |
# |    explained_variance   | 0.0963      |
# |    learning_rate        | 0.01        |
# |    loss                 | 1.36e+03    |
# |    n_updates            | 33230       |
# |    policy_gradient_loss | -0.0259     |
# |    value_loss           | 2.65e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.91        |
# |    ep_rew_mean          | 46.7        |
# | time/                   |             |
# |    fps                  | 128         |
# |    iterations           | 3           |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.022178672 |
# |    clip_fraction        | 0.208       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.73       |
# |    explained_variance   | 0.118       |
# |    learning_rate        | 0.01        |
# |    loss                 | 973         |
# |    n_updates            | 33240       |
# |    policy_gradient_loss | -0.0277     |
# |    value_loss           | 2.12e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4.98       |
# |    ep_rew_mean          | 53.6       |
# | time/                   |            |
# |    fps                  | 128        |
# |    iterations           | 4          |
# |    time_elapsed         | 63         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.01888955 |
# |    clip_fraction        | 0.228      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.73      |
# |    explained_variance   | 0.116      |
# |    learning_rate        | 0.01       |
# |    loss                 | 1.19e+03   |
# |    n_updates            | 33250      |
# |    policy_gradient_loss | -0.0236    |
# |    value_loss           | 3.09e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.11        |
# |    ep_rew_mean          | 51.5        |
# | time/                   |             |
# |    fps                  | 128         |
# |    iterations           | 5           |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.020820264 |
# |    clip_fraction        | 0.221       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.76       |
# |    explained_variance   | 0.175       |
# |    learning_rate        | 0.01        |
# |    loss                 | 1.2e+03     |
# |    n_updates            | 33260       |
# |    policy_gradient_loss | -0.0249     |
# |    value_loss           | 2.36e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.08        |
# |    ep_rew_mean          | 42.5        |
# | time/                   |             |
# |    fps                  | 128         |
# |    iterations           | 6           |
# |    time_elapsed         | 95          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.021688882 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.68       |
# |    explained_variance   | 0.145       |
# |    learning_rate        | 0.01        |
# |    loss                 | 776         |
# |    n_updates            | 33270       |
# |    policy_gradient_loss | -0.0369     |
# |    value_loss           | 1.63e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.89        |
# |    ep_rew_mean          | 53.7        |
# | time/                   |             |
# |    fps                  | 128         |
# |    iterations           | 7           |
# |    time_elapsed         | 111         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.024754204 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.7        |
# |    explained_variance   | 0.0962      |
# |    learning_rate        | 0.01        |
# |    loss                 | 1.52e+03    |
# |    n_updates            | 33280       |
# |    policy_gradient_loss | -0.0196     |
# |    value_loss           | 3.35e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.87       |
# ...
# |    n_updates            | 34140       |
# |    policy_gradient_loss | -0.0207     |
# |    value_loss           | 2.2e+03     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.1        |
# |    ep_rew_mean          | 56.5       |
# | time/                   |            |
# |    fps                  | 126        |
# |    iterations           | 14         |
# |    time_elapsed         | 226        |
# |    total_timesteps      | 28672      |
# | train/                  |            |
# |    approx_kl            | 0.02613323 |
# |    clip_fraction        | 0.245      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.63      |
# |    explained_variance   | 0.143      |
# |    learning_rate        | 0.01       |
# |    loss                 | 731        |
# |    n_updates            | 34150      |
# |    policy_gradient_loss | -0.0359    |
# |    value_loss           | 1.56e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.41        |
# |    ep_rew_mean          | 50.2        |
# | time/                   |             |
# |    fps                  | 126         |
# |    iterations           | 15          |
# |    time_elapsed         | 243         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.020659912 |
# |    clip_fraction        | 0.205       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.62       |
# |    explained_variance   | 0.129       |
# |    learning_rate        | 0.01        |
# |    loss                 | 1.15e+03    |
# |    n_updates            | 34160       |
# |    policy_gradient_loss | -0.0272     |
# |    value_loss           | 2.26e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.75        |
# |    ep_rew_mean          | 38.8        |
# | time/                   |             |
# |    fps                  | 126         |
# |    iterations           | 16          |
# |    time_elapsed         | 258         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.023541361 |
# |    clip_fraction        | 0.229       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.64       |
# |    explained_variance   | 0.116       |
# |    learning_rate        | 0.01        |
# |    loss                 | 2.17e+03    |
# |    n_updates            | 34170       |
# |    policy_gradient_loss | -0.0161     |
# |    value_loss           | 3.58e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.26        |
# |    ep_rew_mean          | 52.3        |
# | time/                   |             |
# |    fps                  | 126         |
# |    iterations           | 17          |
# |    time_elapsed         | 274         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.021609869 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.67       |
# |    explained_variance   | 0.136       |
# |    learning_rate        | 0.01        |
# |    loss                 | 1.1e+03     |
# |    n_updates            | 34180       |
# |    policy_gradient_loss | -0.0302     |
# |    value_loss           | 2.17e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.77        |
# |    ep_rew_mean          | 42.8        |
# | time/                   |             |
# |    fps                  | 127         |
# |    iterations           | 18          |
# |    time_elapsed         | 289         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.024137758 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.71       |
# |    explained_variance   | 0.14        |
# |    learning_rate        | 0.01        |
# |    loss                 | 1.14e+03    |
# |    n_updates            | 34190       |
# |    policy_gradient_loss | -0.0304     |
# |    value_loss           | 2.28e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.1         |
# |    ep_rew_mean          | 38.4        |
# | time/                   |             |
# |    fps                  | 127         |
# |    iterations           | 19          |
# |    time_elapsed         | 305         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.023495786 |
# |    clip_fraction        | 0.244       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.69       |
# |    explained_variance   | 0.163       |
# |    learning_rate        | 0.01        |
# |    loss                 | 1.94e+03    |
# |    n_updates            | 34200       |
# |    policy_gradient_loss | -0.0198     |
# |    value_loss           | 3.29e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.49        |
# |    ep_rew_mean          | 49.1        |
# | time/                   |             |
# |    fps                  | 127         |
# |    iterations           | 20          |
# |    time_elapsed         | 322         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.015191138 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.65       |
# |    explained_variance   | 0.11        |
# |    learning_rate        | 0.01        |
# |    loss                 | 1.79e+03    |
# |    n_updates            | 34210       |
# |    policy_gradient_loss | -0.0223     |
# |    value_loss           | 3.87e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.7         |
# |    ep_rew_mean          | 54.9        |
# | time/                   |             |
# |    fps                  | 127         |
# |    iterations           | 21          |
# |    time_elapsed         | 337         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.023329128 |
# |    clip_fraction        | 0.199       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.63       |
# |    explained_variance   | 0.154       |
# |    learning_rate        | 0.01        |
# |    loss                 | 766         |
# |    n_updates            | 34220       |
# |    policy_gradient_loss | -0.0373     |
# |    value_loss           | 1.67e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.55        |
# |    ep_rew_mean          | 48          |
# | time/                   |             |
# |    fps                  | 127         |
# |    iterations           | 22          |
# |    time_elapsed         | 353         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.017255852 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.69       |
# |    explained_variance   | 0.104       |
# |    learning_rate        | 0.01        |
# |    loss                 | 787         |
# |    n_updates            | 34230       |
# |    policy_gradient_loss | -0.0313     |
# |    value_loss           | 1.67e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.05        |
# |    ep_rew_mean          | 47.5        |
# | time/                   |             |
# |    fps                  | 127         |
# |    iterations           | 23          |
# |    time_elapsed         | 369         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.021783127 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.67       |
# |    explained_variance   | 0.193       |
# |    learning_rate        | 0.01        |
# |    loss                 | 771         |
# |    n_updates            | 34240       |
# |    policy_gradient_loss | -0.0349     |
# |    value_loss           | 1.53e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.47       |
# |    ep_rew_mean          | 50.1       |
# | time/                   |            |
# |    fps                  | 127        |
# |    iterations           | 24         |
# |    time_elapsed         | 385        |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.02540613 |
# |    clip_fraction        | 0.205      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.69      |
# |    explained_variance   | 0.133      |
# |    learning_rate        | 0.01       |
# |    loss                 | 724        |
# |    n_updates            | 34250      |
# |    policy_gradient_loss | -0.0327    |
# |    value_loss           | 1.55e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.73        |
# |    ep_rew_mean          | 36.8        |
# | time/                   |             |
# |    fps                  | 126         |
# |    iterations           | 25          |
# |    time_elapsed         | 404         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.019217372 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.65       |
# |    explained_variance   | 0.139       |
# |    learning_rate        | 0.01        |
# |    loss                 | 1.18e+03    |
# |    n_updates            | 34260       |
# |    policy_gradient_loss | -0.0212     |
# |    value_loss           | 2.65e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.09        |
# |    ep_rew_mean          | 38.3        |
# | time/                   |             |
# |    fps                  | 126         |
# |    iterations           | 26          |
# |    time_elapsed         | 420         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.018453237 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.72       |
# |    explained_variance   | 0.0818      |
# |    learning_rate        | 0.01        |
# |    loss                 | 1.71e+03    |
# |    n_updates            | 34270       |
# |    policy_gradient_loss | -0.0198     |
# |    value_loss           | 3.94e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.87        |
# |    ep_rew_mean          | 46.6        |
# | time/                   |             |
# |    fps                  | 126         |
# |    iterations           | 27          |
# |    time_elapsed         | 436         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.020139072 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.64       |
# |    explained_variance   | 0.146       |
# |    learning_rate        | 0.01        |
# |    loss                 | 782         |
# |    n_updates            | 34280       |
# |    policy_gradient_loss | -0.0335     |
# |    value_loss           | 1.62e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.96        |
# |    ep_rew_mean          | 50.6        |
# | time/                   |             |
# |    fps                  | 126         |
# |    iterations           | 28          |
# |    time_elapsed         | 451         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.026401637 |
# |    clip_fraction        | 0.205       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.66       |
# |    explained_variance   | 0.104       |
# |    learning_rate        | 0.01        |
# |    loss                 | 1.21e+03    |
# |    n_updates            | 34290       |
# |    policy_gradient_loss | -0.0239     |
# |    value_loss           | 2.4e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.61        |
# |    ep_rew_mean          | 49.9        |
# | time/                   |             |
# |    fps                  | 127         |
# |    iterations           | 29          |
# |    time_elapsed         | 467         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.028206171 |
# |    clip_fraction        | 0.233       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.67       |
# |    explained_variance   | 0.146       |
# |    learning_rate        | 0.01        |
# |    loss                 | 752         |
# |    n_updates            | 34300       |
# |    policy_gradient_loss | -0.0411     |
# |    value_loss           | 1.59e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.62       |
# |    ep_rew_mean          | 48.9       |
# | time/                   |            |
# |    fps                  | 127        |
# |    iterations           | 30         |
# |    time_elapsed         | 483        |
# |    total_timesteps      | 61440      |
# | train/                  |            |
# |    approx_kl            | 0.02434316 |
# |    clip_fraction        | 0.249      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.68      |
# |    explained_variance   | 0.116      |
# |    learning_rate        | 0.01       |
# |    loss                 | 1.19e+03   |
# |    n_updates            | 34310      |
# |    policy_gradient_loss | -0.0217    |
# |    value_loss           | 2.22e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.07        |
# |    ep_rew_mean          | 57.6        |
# | time/                   |             |
# |    fps                  | 126         |
# |    iterations           | 31          |
# |    time_elapsed         | 500         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.023193052 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.65       |
# |    explained_variance   | 0.112       |
# |    learning_rate        | 0.01        |
# |    loss                 | 1.39e+03    |
# |    n_updates            | 34320       |
# |    policy_gradient_loss | -0.0186     |
# |    value_loss           | 3.41e+03    |
# -----------------------------------------
